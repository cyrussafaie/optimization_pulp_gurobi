# %%
# from gurobipy import *   (MW check to see why Ehsan added the *)
#  Ask Why we have all these other imports and why we are doing the other things and if we run this just once
# from pulp import *
import pandas as pd
from itertools import permutations
from collections import defaultdict
import matplotlib.pyplot as plt
import time

# %%
from pulp import *

# Create the 'prob' variable to contain the problem data
prob = LpProblem("Beer and Ale",LpMaximize)

# The 2 variables Ale and Beer are created with a lower limit of 0
A=LpVariable("Ale",0,None,LpContinuous)
B=LpVariable("Beer",0,None, LpContinuous)

# The objective function is added to 'prob' first
prob += 13*A + 23*B, "Total Revenue of Production Plan"

# The three constraints are entered
prob += 5*A + 15*B <= 480, "Corn"
prob += 4*A + 4*B <= 160, "Hops"
prob += 35*A + 20*B <= 1190, "Malt"

# The problem data is written to an .lp file
prob.writeLP("BeerAle.lp")

# The problem is solved using PuLP's choice of Solver
prob.solve()

# The status of the solution is printed to the screen
print("Status:", LpStatus[prob.status])

# Each of the variables is printed with it's resolved optimum value
for v in prob.variables():
    print(v.name, "=", v.varValue)
    
# The optimised objective function value is printed to the screen
print("Total Revenue of Plan = ", value(prob.objective))

# Each of the constraints is printed with it's LHS value
#for c in prob.Constraints():
#    print(c.name, "=", c.conValue)

for constraint in prob.constraints:
        # print(prob.constraints[constraint].name, prob.constraints[constraint].value() - prob.constraints[constraint].constant)
        print(prob.constraints[constraint].name, prob.constraints[constraint].value())
        print(prob.constraints[constraint].name, prob.constraints[constraint].constant)
# Out:
# Status: Optimal
# Ale = 12.0
# Beer = 28.0
# Total Revenue of Plan =  800.0
# Corn 0.0
# Corn -480
# Hops 0.0
# Hops -160
# Malt -210.0
# Malt -1190

# %%
# This model separates the data from the optimization model

from pulp import *

#Create a list of all the products
Products = ["Ale","Beer"]

#Create a dictionary of the prices for products
Prices = {"Ale": 13,
         "Beer":23}

#Create a list of all the raw materials
RawMaterials = ["Corn","Hops","Malt"]

#Create a Dictionary of Amount of each Raw Material Available
RawAvailability = {"Corn": 480,
                  "Hops": 160,
                  "Malt": 1190}

#Create a list for amount used of each raw material for each product
AmountUsed = {"Ale": {"Corn": 5, "Hops": 4, "Malt": 35},
              "Beer":{"Corn": 15, "Hops": 4, "Malt": 20}
             }

# Create the 'prob' variable to contain the problem data
prob = LpProblem("Beer and Ale",LpMaximize)

# Create the Variables
product_vars = LpVariable.dicts("Prods",Products,lowBound=0,upBound=None,cat=LpContinuous)

# The objective function is added to 'prob' first
prob += lpSum([Prices[i]*product_vars[i] for i in Products]), "Total Revenue of Production Plan"

# We can enter the constraints that relate to limited amount of material
for r in RawMaterials:
    prob += lpSum([product_vars[i]*AmountUsed[i][r] for i in Products]) <= RawAvailability[r]

# The problem data is written to an .lp file
prob.writeLP("BeerAle.lp")

# The problem is solved using PuLP's choice of Solver
prob.solve()

# The status of the solution is printed to the screen
print("Status:", LpStatus[prob.status])

# Each of the variables is printed with it's resolved optimum value
for v in prob.variables():
    print(v.name, "=", v.varValue)
    
# The optimised objective function value is printed to the screen
print("Total Revenue of Plan = ", value(prob.objective))

# Each of the constraints is printed with it's LHS value
#for c in prob.Constraints():
#    print(c.name, "=", c.conValue)

for constraint in prob.constraints:
        # print(prob.constraints[constraint].name, prob.constraints[constraint].value() - prob.constraints[constraint].constant)
        print(prob.constraints[constraint].name, prob.constraints[constraint].value())
        print(prob.constraints[constraint].name, prob.constraints[constraint].constant)
# Out:
# Status: Optimal
# Prods_Ale = 12.0
# Prods_Beer = 28.0
# Total Revenue of Plan =  800.0
# None 0.0
# None -480
# None 0.0
# None -160
# None -210.0
# None -1190

# %%
# This is a simple version to test different values
from pulp import *

for x in range(0,101):


    # Create the 'prob' variable to contain the problem data
    prob = LpProblem("Beer and Ale",LpMaximize)

    # The 2 variables Ale and Beer are created with a lower limit of 0
    A=LpVariable("Ale",0,None,LpContinuous)
    B=LpVariable("Beer",0,None, LpContinuous)


    #Different Amounts of Raw Material Bought  Toggle the "+x" off or on to test different variables.
    Corn = 480 + x
    Hops = 160 + x
    Malt = 1190 + x
    

    # The objective function is added to 'prob' first
    prob += Wgt*(13*A + 23*B), "Total Revenue"

    # The three constraints are entered
    prob += 5*A + 15*B <= Corn, "Corn"
    prob += 4*A + 4*B <= Hops, "Hops"
    prob += 35*A + 20*B <= Malt, "Malt"

    # The problem data is written to an .lp file
    prob.writeLP("BeerAle.lp")

    # The problem is solved using PuLP's choice of Solver
    prob.solve()

    # The status of the solution is printed to the screen
    print("---------------------")
    print("Status:", LpStatus[prob.status])

    # Each of the variables is printed with it's resolved optimum value
    for v in prob.variables():
        print(v.name, "=", v.varValue)

    # The optimised objective function value is printed to the screen
    print("Total Objective Value = ", value(prob.objective))

    #Actual total profit.  NOTE:  The profit changed here too....
    #print("Real Total Profit",25*A.varValue+10*B.varValue)  

    #Total Barrels
    print("Total Barrels Made",A.varValue+B.varValue)
    print ("Corn", Corn)
    print ("Hops",Hops)
    print ("Malt",Malt)

    # Each of the constraints is printed with it's LHS value
    #for c in prob.Constraints():
    #    print(c.name, "=", c.conValue)

    #for constraint in prob.constraints:
            # print(prob.constraints[constraint].name, prob.constraints[constraint].value() - prob.constraints[constraint].constant)
    #        print(prob.constraints[constraint].name, prob.constraints[constraint].value())
    #        print(prob.constraints[constraint].name, prob.constraints[constraint].constant)
# Out:
# ---------------------
# Status: Optimal
# Ale = 12.0
# Beer = 28.0
# Total Objective Value =  800.0
# Total Barrels Made 40.0
# Corn 480
# Hops 160
# Malt 1190
# ---------------------
# Status: Optimal
# Ale = 12.275
# Beer = 27.975
# Total Objective Value =  803.0000000000001
# Total Barrels Made 40.25
# Corn 481
# Hops 161
# Malt 1191
# ---------------------
# Status: Optimal
# Ale = 12.55
# Beer = 27.95
# Total Objective Value =  806.0
# Total Barrels Made 40.5
# Corn 482
# Hops 162
# Malt 1192
# ---------------------
# Status: Optimal
# Ale = 12.825
# Beer = 27.925
# Total Objective Value =  809.0
# Total Barrels Made 40.75
# Corn 483
# Hops 163
# Malt 1193
# ---------------------
# Status: Optimal
# Ale = 13.1
# Beer = 27.9
# Total Objective Value =  811.9999999999999
# Total Barrels Made 41.0
# Corn 484
# Hops 164
# Malt 1194
# ---------------------
# Status: Optimal
# Ale = 13.375
# Beer = 27.875
# Total Objective Value =  815.0
# Total Barrels Made 41.25
# Corn 485
# Hops 165
# Malt 1195
# ---------------------
# Status: Optimal
# Ale = 13.65
# Beer = 27.85
# Total Objective Value =  818.0000000000001
# Total Barrels Made 41.5
# Corn 486
# Hops 166
# Malt 1196
# ---------------------
# Status: Optimal
# Ale = 13.925
# Beer = 27.825
# Total Objective Value =  821.0
# Total Barrels Made 41.75
# Corn 487
# Hops 167
# Malt 1197
# ---------------------
# Status: Optimal
# Ale = 14.2
# Beer = 27.8
# Total Objective Value =  824.0
# Total Barrels Made 42.0
# Corn 488
# Hops 168
# Malt 1198
# ---------------------
# Status: Optimal
# Ale = 14.475
# Beer = 27.775
# Total Objective Value =  826.9999999999999
# Total Barrels Made 42.25
# Corn 489
# Hops 169
# Malt 1199
# ---------------------
# Status: Optimal
# Ale = 14.75
# Beer = 27.75
# Total Objective Value =  830.0
# Total Barrels Made 42.5
# Corn 490
# Hops 170
# Malt 1200
# ---------------------
# Status: Optimal
# Ale = 15.025
# Beer = 27.725
# Total Objective Value =  833.0000000000001
# Total Barrels Made 42.75
# Corn 491
# Hops 171
# Malt 1201
# ---------------------
# Status: Optimal
# Ale = 15.3
# Beer = 27.7
# Total Objective Value =  836.0
# Total Barrels Made 43.0
# Corn 492
# Hops 172
# Malt 1202
# ---------------------
# Status: Optimal
# Ale = 15.575
# Beer = 27.675
# Total Objective Value =  839.0
# Total Barrels Made 43.25
# Corn 493
# Hops 173
# Malt 1203
# ---------------------
# Status: Optimal
# Ale = 15.85
# Beer = 27.65
# Total Objective Value =  841.9999999999999
# Total Barrels Made 43.5
# Corn 494
# Hops 174
# Malt 1204
# ---------------------
# Status: Optimal
# Ale = 16.125
# Beer = 27.625
# Total Objective Value =  845.0
# Total Barrels Made 43.75
# Corn 495
# Hops 175
# Malt 1205
# ---------------------
# Status: Optimal
# Ale = 16.4
# Beer = 27.6
# Total Objective Value =  848.0
# Total Barrels Made 44.0
# Corn 496
# Hops 176
# Malt 1206
# ---------------------
# Status: Optimal
# Ale = 16.675
# Beer = 27.575
# Total Objective Value =  851.0
# Total Barrels Made 44.25
# Corn 497
# Hops 177
# Malt 1207
# ---------------------
# Status: Optimal
# Ale = 16.95
# Beer = 27.55
# Total Objective Value =  854.0
# Total Barrels Made 44.5
# Corn 498
# Hops 178
# Malt 1208
# ---------------------
# Status: Optimal
# Ale = 17.225
# Beer = 27.525
# Total Objective Value =  857.0
# Total Barrels Made 44.75
# Corn 499
# Hops 179
# Malt 1209
# ---------------------
# Status: Optimal
# Ale = 17.5
# Beer = 27.5
# Total Objective Value =  860.0
# Total Barrels Made 45.0
# Corn 500
# Hops 180
# Malt 1210
# ---------------------
# Status: Optimal
# Ale = 17.775
# Beer = 27.475
# Total Objective Value =  863.0
# Total Barrels Made 45.25
# Corn 501
# Hops 181
# Malt 1211
# ---------------------
# Status: Optimal
# Ale = 18.05
# Beer = 27.45
# Total Objective Value =  866.0
# Total Barrels Made 45.5
# Corn 502
# Hops 182
# Malt 1212
# ---------------------
# Status: Optimal
# Ale = 18.325
# Beer = 27.425
# Total Objective Value =  869.0
# Total Barrels Made 45.75
# Corn 503
# Hops 183
# Malt 1213
# ---------------------
# Status: Optimal
# Ale = 18.6
# Beer = 27.4
# Total Objective Value =  872.0
# Total Barrels Made 46.0
# Corn 504
# Hops 184
# Malt 1214
# ---------------------
# Status: Optimal
# Ale = 18.875
# Beer = 27.375
# Total Objective Value =  875.0
# Total Barrels Made 46.25
# Corn 505
# Hops 185
# Malt 1215
# ---------------------
# Status: Optimal
# Ale = 19.105882
# Beer = 27.364706
# Total Objective Value =  877.764704
# Total Barrels Made 46.470588000000006
# Corn 506
# Hops 186
# Malt 1216
# ---------------------
# Status: Optimal
# Ale = 19.094118
# Beer = 27.435294
# Total Objective Value =  879.2352960000001
# Total Barrels Made 46.529412
# Corn 507
# Hops 187
# Malt 1217
# ---------------------
# Status: Optimal
# Ale = 19.082353
# Beer = 27.505882
# Total Objective Value =  880.705875
# Total Barrels Made 46.588235
# Corn 508
# Hops 188
# Malt 1218
# ---------------------
# Status: Optimal
# Ale = 19.070588
# Beer = 27.576471
# Total Objective Value =  882.176477
# Total Barrels Made 46.647059
# Corn 509
# Hops 189
# Malt 1219
# ---------------------
# Status: Optimal
# Ale = 19.058824
# Beer = 27.647059
# Total Objective Value =  883.647069
# Total Barrels Made 46.705883
# Corn 510
# Hops 190
# Malt 1220
# ---------------------
# Status: Optimal
# Ale = 19.047059
# Beer = 27.717647
# Total Objective Value =  885.117648
# Total Barrels Made 46.764706000000004
# Corn 511
# Hops 191
# Malt 1221
# ---------------------
# Status: Optimal
# Ale = 19.035294
# Beer = 27.788235
# Total Objective Value =  886.588227
# Total Barrels Made 46.823529
# Corn 512
# Hops 192
# Malt 1222
# ---------------------
# Status: Optimal
# Ale = 19.023529
# Beer = 27.858824
# Total Objective Value =  888.058829
# Total Barrels Made 46.882352999999995
# Corn 513
# Hops 193
# Malt 1223
# ---------------------
# Status: Optimal
# Ale = 19.011765
# Beer = 27.929412
# Total Objective Value =  889.5294210000001
# Total Barrels Made 46.941176999999996
# Corn 514
# Hops 194
# Malt 1224
# ---------------------
# Status: Optimal
# Ale = 19.0
# Beer = 28.0
# Total Objective Value =  891.0
# Total Barrels Made 47.0
# Corn 515
# Hops 195
# Malt 1225
# ---------------------
# Status: Optimal
# Ale = 18.988235
# Beer = 28.070588
# Total Objective Value =  892.4705789999999
# Total Barrels Made 47.058823000000004
# Corn 516
# Hops 196
# Malt 1226
# ---------------------
# Status: Optimal
# Ale = 18.976471
# Beer = 28.141176
# Total Objective Value =  893.941171
# Total Barrels Made 47.117647000000005
# Corn 517
# Hops 197
# Malt 1227
# ---------------------
# Status: Optimal
# Ale = 18.964706
# Beer = 28.211765
# Total Objective Value =  895.411773
# Total Barrels Made 47.176471
# Corn 518
# Hops 198
# Malt 1228
# ---------------------
# Status: Optimal
# Ale = 18.952941
# Beer = 28.282353
# Total Objective Value =  896.882352
# Total Barrels Made 47.235293999999996
# Corn 519
# Hops 199
# Malt 1229
# ---------------------
# Status: Optimal
# Ale = 18.941176
# Beer = 28.352941
# Total Objective Value =  898.352931
# Total Barrels Made 47.294117
# Corn 520
# Hops 200
# Malt 1230
# ---------------------
# Status: Optimal
# Ale = 18.929412
# Beer = 28.423529
# Total Objective Value =  899.823523
# Total Barrels Made 47.352941
# Corn 521
# Hops 201
# Malt 1231
# ---------------------
# Status: Optimal
# Ale = 18.917647
# Beer = 28.494118
# Total Objective Value =  901.294125
# Total Barrels Made 47.411765
# Corn 522
# Hops 202
# Malt 1232
# ---------------------
# Status: Optimal
# Ale = 18.905882
# Beer = 28.564706
# Total Objective Value =  902.7647039999999
# Total Barrels Made 47.470588
# Corn 523
# Hops 203
# Malt 1233
# ---------------------
# Status: Optimal
# Ale = 18.894118
# Beer = 28.635294
# Total Objective Value =  904.235296
# Total Barrels Made 47.529411999999994
# Corn 524
# Hops 204
# Malt 1234
# ---------------------
# Status: Optimal
# Ale = 18.882353
# Beer = 28.705882
# Total Objective Value =  905.705875
# Total Barrels Made 47.588235
# Corn 525
# Hops 205
# Malt 1235
# ---------------------
# Status: Optimal
# Ale = 18.870588
# Beer = 28.776471
# Total Objective Value =  907.176477
# Total Barrels Made 47.647059
# Corn 526
# Hops 206
# Malt 1236
# ---------------------
# Status: Optimal
# Ale = 18.858824
# Beer = 28.847059
# Total Objective Value =  908.6470690000001
# Total Barrels Made 47.705883
# Corn 527
# Hops 207
# Malt 1237
# ---------------------
# Status: Optimal
# Ale = 18.847059
# Beer = 28.917647
# Total Objective Value =  910.1176479999999
# Total Barrels Made 47.764706000000004
# Corn 528
# Hops 208
# Malt 1238
# ---------------------
# Status: Optimal
# Ale = 18.835294
# Beer = 28.988235
# Total Objective Value =  911.5882270000001
# Total Barrels Made 47.823529
# Corn 529
# Hops 209
# Malt 1239
# ---------------------
# Status: Optimal
# Ale = 18.823529
# Beer = 29.058824
# Total Objective Value =  913.0588290000001
# Total Barrels Made 47.882353
# Corn 530
# Hops 210
# Malt 1240
# ---------------------
# Status: Optimal
# Ale = 18.811765
# Beer = 29.129412
# Total Objective Value =  914.529421
# Total Barrels Made 47.941176999999996
# Corn 531
# Hops 211
# Malt 1241
# ---------------------
# Status: Optimal
# Ale = 18.8
# Beer = 29.2
# Total Objective Value =  916.0
# Total Barrels Made 48.0
# Corn 532
# Hops 212
# Malt 1242
# ---------------------
# Status: Optimal
# Ale = 18.788235
# Beer = 29.270588
# Total Objective Value =  917.470579
# Total Barrels Made 48.058823000000004
# Corn 533
# Hops 213
# Malt 1243
# ---------------------
# Status: Optimal
# Ale = 18.776471
# Beer = 29.341176
# Total Objective Value =  918.9411709999999
# Total Barrels Made 48.117647000000005
# Corn 534
# Hops 214
# Malt 1244
# ---------------------
# Status: Optimal
# Ale = 18.764706
# Beer = 29.411765
# Total Objective Value =  920.411773
# Total Barrels Made 48.176471
# Corn 535
# Hops 215
# Malt 1245
# ---------------------
# Status: Optimal
# Ale = 18.752941
# Beer = 29.482353
# Total Objective Value =  921.882352
# Total Barrels Made 48.235293999999996
# Corn 536
# Hops 216
# Malt 1246
# ---------------------
# Status: Optimal
# Ale = 18.741176
# Beer = 29.552941
# Total Objective Value =  923.3529310000001
# Total Barrels Made 48.294117
# Corn 537
# Hops 217
# Malt 1247
# ---------------------
# Status: Optimal
# Ale = 18.729412
# Beer = 29.623529
# Total Objective Value =  924.823523
# Total Barrels Made 48.352941
# Corn 538
# Hops 218
# Malt 1248
# ---------------------
# Status: Optimal
# Ale = 18.717647
# Beer = 29.694118
# Total Objective Value =  926.2941249999999
# Total Barrels Made 48.411765
# Corn 539
# Hops 219
# Malt 1249
# ---------------------
# Status: Optimal
# Ale = 18.705882
# Beer = 29.764706
# Total Objective Value =  927.764704
# Total Barrels Made 48.470588
# Corn 540
# Hops 220
# Malt 1250
# ---------------------
# Status: Optimal
# Ale = 18.694118
# Beer = 29.835294
# Total Objective Value =  929.2352960000001
# Total Barrels Made 48.529412
# Corn 541
# Hops 221
# Malt 1251
# ---------------------
# Status: Optimal
# Ale = 18.682353
# Beer = 29.905882
# Total Objective Value =  930.705875
# Total Barrels Made 48.588235
# Corn 542
# Hops 222
# Malt 1252
# ---------------------
# Status: Optimal
# Ale = 18.670588
# Beer = 29.976471
# Total Objective Value =  932.176477
# Total Barrels Made 48.647059
# Corn 543
# Hops 223
# Malt 1253
# ---------------------
# Status: Optimal
# Ale = 18.658824
# Beer = 30.047059
# Total Objective Value =  933.647069
# Total Barrels Made 48.705883
# Corn 544
# Hops 224
# Malt 1254
# ---------------------
# Status: Optimal
# Ale = 18.647059
# Beer = 30.117647
# Total Objective Value =  935.1176480000001
# Total Barrels Made 48.764706000000004
# Corn 545
# Hops 225
# Malt 1255
# ---------------------
# Status: Optimal
# Ale = 18.635294
# Beer = 30.188235
# Total Objective Value =  936.588227
# Total Barrels Made 48.82352899999999
# Corn 546
# Hops 226
# Malt 1256
# ---------------------
# Status: Optimal
# Ale = 18.623529
# Beer = 30.258824
# Total Objective Value =  938.0588290000001
# Total Barrels Made 48.882353
# Corn 547
# Hops 227
# Malt 1257
# ---------------------
# Status: Optimal
# Ale = 18.611765
# Beer = 30.329412
# Total Objective Value =  939.5294210000001
# Total Barrels Made 48.941176999999996
# Corn 548
# Hops 228
# Malt 1258
# ---------------------
# Status: Optimal
# Ale = 18.6
# Beer = 30.4
# Total Objective Value =  941.0
# Total Barrels Made 49.0
# Corn 549
# Hops 229
# Malt 1259
# ---------------------
# Status: Optimal
# Ale = 18.588235
# Beer = 30.470588
# Total Objective Value =  942.470579
# Total Barrels Made 49.058823000000004
# Corn 550
# Hops 230
# Malt 1260
# ---------------------
# Status: Optimal
# Ale = 18.576471
# Beer = 30.541176
# Total Objective Value =  943.941171
# Total Barrels Made 49.117647000000005
# Corn 551
# Hops 231
# Malt 1261
# ---------------------
# Status: Optimal
# Ale = 18.564706
# Beer = 30.611765
# Total Objective Value =  945.4117729999999
# Total Barrels Made 49.176471
# Corn 552
# Hops 232
# Malt 1262
# ---------------------
# Status: Optimal
# Ale = 18.552941
# Beer = 30.682353
# Total Objective Value =  946.882352
# Total Barrels Made 49.235293999999996
# Corn 553
# Hops 233
# Malt 1263
# ---------------------
# Status: Optimal
# Ale = 18.541176
# Beer = 30.752941
# Total Objective Value =  948.352931
# Total Barrels Made 49.294117
# Corn 554
# Hops 234
# Malt 1264
# ---------------------
# Status: Optimal
# Ale = 18.529412
# Beer = 30.823529
# Total Objective Value =  949.823523
# Total Barrels Made 49.352941
# Corn 555
# Hops 235
# Malt 1265
# ---------------------
# Status: Optimal
# Ale = 18.517647
# Beer = 30.894118
# Total Objective Value =  951.294125
# Total Barrels Made 49.411765
# Corn 556
# Hops 236
# Malt 1266
# ---------------------
# Status: Optimal
# Ale = 18.505882
# Beer = 30.964706
# Total Objective Value =  952.7647039999999
# Total Barrels Made 49.470588
# Corn 557
# Hops 237
# Malt 1267
# ---------------------
# Status: Optimal
# Ale = 18.494118
# Beer = 31.035294
# Total Objective Value =  954.2352960000001
# Total Barrels Made 49.529412
# Corn 558
# Hops 238
# Malt 1268
# ---------------------
# Status: Optimal
# Ale = 18.482353
# Beer = 31.105882
# Total Objective Value =  955.705875
# Total Barrels Made 49.588235
# Corn 559
# Hops 239
# Malt 1269
# ---------------------
# Status: Optimal
# Ale = 18.470588
# Beer = 31.176471
# Total Objective Value =  957.176477
# Total Barrels Made 49.647059
# Corn 560
# Hops 240
# Malt 1270
# ---------------------
# Status: Optimal
# Ale = 18.458824
# Beer = 31.247059
# Total Objective Value =  958.647069
# Total Barrels Made 49.705883
# Corn 561
# Hops 241
# Malt 1271
# ---------------------
# Status: Optimal
# Ale = 18.447059
# Beer = 31.317647
# Total Objective Value =  960.117648
# Total Barrels Made 49.764706000000004
# Corn 562
# Hops 242
# Malt 1272
# ---------------------
# Status: Optimal
# Ale = 18.435294
# Beer = 31.388235
# Total Objective Value =  961.5882270000001
# Total Barrels Made 49.823529
# Corn 563
# Hops 243
# Malt 1273
# ---------------------
# Status: Optimal
# Ale = 18.423529
# Beer = 31.458824
# Total Objective Value =  963.058829
# Total Barrels Made 49.882352999999995
# Corn 564
# Hops 244
# Malt 1274
# ---------------------
# Status: Optimal
# Ale = 18.411765
# Beer = 31.529412
# Total Objective Value =  964.529421
# Total Barrels Made 49.941176999999996
# Corn 565
# Hops 245
# Malt 1275
# ---------------------
# Status: Optimal
# Ale = 18.4
# Beer = 31.6
# Total Objective Value =  966.0
# Total Barrels Made 50.0
# Corn 566
# Hops 246
# Malt 1276
# ---------------------
# Status: Optimal
# Ale = 18.388235
# Beer = 31.670588
# Total Objective Value =  967.4705789999999
# Total Barrels Made 50.058823000000004
# Corn 567
# Hops 247
# Malt 1277
# ---------------------
# Status: Optimal
# Ale = 18.376471
# Beer = 31.741176
# Total Objective Value =  968.9411709999999
# Total Barrels Made 50.117647
# Corn 568
# Hops 248
# Malt 1278
# ---------------------
# Status: Optimal
# Ale = 18.364706
# Beer = 31.811765
# Total Objective Value =  970.411773
# Total Barrels Made 50.17647100000001
# Corn 569
# Hops 249
# Malt 1279
# ---------------------
# Status: Optimal
# Ale = 18.352941
# Beer = 31.882353
# Total Objective Value =  971.8823519999999
# Total Barrels Made 50.235293999999996
# Corn 570
# Hops 250
# Malt 1280
# ---------------------
# Status: Optimal
# Ale = 18.341176
# Beer = 31.952941
# Total Objective Value =  973.352931
# Total Barrels Made 50.294117
# Corn 571
# Hops 251
# Malt 1281
# ---------------------
# Status: Optimal
# Ale = 18.329412
# Beer = 32.023529
# Total Objective Value =  974.8235230000001
# Total Barrels Made 50.352941
# Corn 572
# Hops 252
# Malt 1282
# ---------------------
# Status: Optimal
# Ale = 18.317647
# Beer = 32.094118
# Total Objective Value =  976.294125
# Total Barrels Made 50.411765
# Corn 573
# Hops 253
# Malt 1283
# ---------------------
# Status: Optimal
# Ale = 18.305882
# Beer = 32.164706
# Total Objective Value =  977.7647040000002
# Total Barrels Made 50.470588000000006
# Corn 574
# Hops 254
# Malt 1284
# ---------------------
# Status: Optimal
# Ale = 18.294118
# Beer = 32.235294
# Total Objective Value =  979.2352960000001
# Total Barrels Made 50.52941200000001
# Corn 575
# Hops 255
# Malt 1285
# ---------------------
# Status: Optimal
# Ale = 18.282353
# Beer = 32.305882
# Total Objective Value =  980.7058749999999
# Total Barrels Made 50.588235
# Corn 576
# Hops 256
# Malt 1286
# ---------------------
# Status: Optimal
# Ale = 18.270588
# Beer = 32.376471
# Total Objective Value =  982.1764770000001
# Total Barrels Made 50.647059
# Corn 577
# Hops 257
# Malt 1287
# ---------------------
# Status: Optimal
# Ale = 18.258824
# Beer = 32.447059
# Total Objective Value =  983.6470690000001
# Total Barrels Made 50.705883
# Corn 578
# Hops 258
# Malt 1288
# ---------------------
# Status: Optimal
# Ale = 18.247059
# Beer = 32.517647
# Total Objective Value =  985.1176479999999
# Total Barrels Made 50.764706
# Corn 579
# Hops 259
# Malt 1289
# ---------------------
# Status: Optimal
# Ale = 18.235294
# Beer = 32.588235
# Total Objective Value =  986.588227
# Total Barrels Made 50.82352899999999
# Corn 580
# Hops 260
# Malt 1290

# %%
# This is a simple multi Objective Version
from pulp import *

for w in range(0,101):


    # Create the 'prob' variable to contain the problem data
    prob = LpProblem("Beer and Ale",LpMaximize)

    # The 2 variables Ale and Beer are created with a lower limit of 0
    A=LpVariable("Ale",0,None,LpContinuous)
    B=LpVariable("Beer",0,None, LpContinuous)


    #Weights for the different parts of the objective
    Wgt = w/100
    Wgt1 = 1-Wgt

    # The objective function is added to 'prob' first
    prob += Wgt*(25*A + 10*B) + Wgt1*(B+A), "NOTE:  We chenged the profit.  Total revenue with a factor to minimimze the extra Beer-- this only works when you know you'll make more Beer"

    # The three constraints are entered
    prob += 5*A + 15*B <= 480, "Corn"
    prob += 4*A + 4*B <= 160, "Hops"
    prob += 35*A + 20*B <= 1190, "Malt"

    # The problem data is written to an .lp file
    prob.writeLP("BeerAle.lp")

    # The problem is solved using PuLP's choice of Solver
    prob.solve()

    # The status of the solution is printed to the screen
    print("---------------------")
    print("Status:", LpStatus[prob.status])

    # Each of the variables is printed with it's resolved optimum value
    for v in prob.variables():
        print(v.name, "=", v.varValue)

    # The optimised objective function value is printed to the screen
    print("Total Objective Value = ", value(prob.objective))

    #Actual total profit.  NOTE:  The profit changed here too....
    print("Real Total Profit",25*A.varValue+10*B.varValue)  

    #Total Barrels
    print("Total Barrels Made",A.varValue+B.varValue)
    print ("Weights", Wgt, Wgt1)

    # Each of the constraints is printed with it's LHS value
    #for c in prob.Constraints():
    #    print(c.name, "=", c.conValue)

    #for constraint in prob.constraints:
            # print(prob.constraints[constraint].name, prob.constraints[constraint].value() - prob.constraints[constraint].constant)
    #        print(prob.constraints[constraint].name, prob.constraints[constraint].value())
    #        print(prob.constraints[constraint].name, prob.constraints[constraint].constant)
# Out:
# ---------------------
# Status: Optimal
# Ale = 12.0
# Beer = 28.0
# Total Objective Value =  40.0
# Real Total Profit 580.0
# Total Barrels Made 40.0
# Weights 0.0 1.0
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  47.5
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.01 0.99
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  55.0
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.02 0.98
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  62.5
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.03 0.97
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  70.0
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.04 0.96
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  77.5
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.05 0.95
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  85.0
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.06 0.94
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  92.5
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.07 0.9299999999999999
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  100.0
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.08 0.92
# ---------------------
# Status: Optimal
# Ale = 26.0
# Beer = 14.0
# Total Objective Value =  107.5
# Real Total Profit 790.0
# Total Barrels Made 40.0
# Weights 0.09 0.91
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  115.6
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.1 0.9
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  123.76
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.11 0.89
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  131.92
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.12 0.88
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  140.08
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.13 0.87
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  148.24
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.14 0.86
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  156.39999999999998
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.15 0.85
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  164.56
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.16 0.84
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  172.72
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.17 0.83
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  180.88
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.18 0.8200000000000001
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  189.04000000000002
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.19 0.81
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  197.2
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.2 0.8
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  205.36
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.21 0.79
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  213.52
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.22 0.78
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  221.67999999999998
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.23 0.77
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  229.84
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.24 0.76
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  238.0
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.25 0.75
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  246.16
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.26 0.74
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  254.32000000000002
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.27 0.73
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  262.48
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.28 0.72
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  270.64
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.29 0.71
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  278.79999999999995
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.3 0.7
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  286.96
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.31 0.69
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  295.12
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.32 0.6799999999999999
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  303.28
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.33 0.6699999999999999
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  311.44
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.34 0.6599999999999999
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  319.6
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.35 0.65
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  327.76
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.36 0.64
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  335.92
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.37 0.63
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  344.08
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.38 0.62
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  352.24
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.39 0.61
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  360.4
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.4 0.6
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  368.56
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.41 0.5900000000000001
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  376.72
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.42 0.5800000000000001
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  384.88
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.43 0.5700000000000001
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  393.04
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.44 0.56
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  401.20000000000005
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.45 0.55
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  409.35999999999996
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.46 0.54
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  417.52
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.47 0.53
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  425.68
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.48 0.52
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  433.84
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.49 0.51
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  442.0
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.5 0.5
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  450.16
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.51 0.49
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  458.32
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.52 0.48
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  466.48
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.53 0.47
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  474.64000000000004
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.54 0.45999999999999996
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  482.8
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.55 0.44999999999999996
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  490.96000000000004
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.56 0.43999999999999995
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  499.11999999999995
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.57 0.43000000000000005
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  507.2799999999999
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.58 0.42000000000000004
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  515.44
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.59 0.41000000000000003
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  523.6
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.6 0.4
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  531.76
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.61 0.39
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  539.9200000000001
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.62 0.38
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  548.08
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.63 0.37
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  556.24
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.64 0.36
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  564.4000000000001
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.65 0.35
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  572.56
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.66 0.33999999999999997
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  580.7199999999999
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.67 0.32999999999999996
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  588.88
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.68 0.31999999999999995
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  597.04
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.69 0.31000000000000005
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  605.2
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.7 0.30000000000000004
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  613.36
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.71 0.29000000000000004
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  621.52
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.72 0.28
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  629.68
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.73 0.27
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  637.84
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.74 0.26
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  646.0
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.75 0.25
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  654.16
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.76 0.24
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  662.32
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.77 0.22999999999999998
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  670.48
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.78 0.21999999999999997
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  678.64
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.79 0.20999999999999996
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  686.8
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.8 0.19999999999999996
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  694.96
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.81 0.18999999999999995
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  703.12
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.82 0.18000000000000005
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  711.2800000000001
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.83 0.17000000000000004
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  719.44
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.84 0.16000000000000003
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  727.5999999999999
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.85 0.15000000000000002
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  735.76
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.86 0.14
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  743.92
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.87 0.13
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  752.08
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.88 0.12
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  760.24
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.89 0.10999999999999999
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  768.4000000000001
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.9 0.09999999999999998
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  776.56
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.91 0.08999999999999997
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  784.7199999999999
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.92 0.07999999999999996
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  792.88
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.93 0.06999999999999995
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  801.04
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.94 0.06000000000000005
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  809.2
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.95 0.050000000000000044
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  817.36
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.96 0.040000000000000036
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  825.52
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.97 0.030000000000000027
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  833.68
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.98 0.020000000000000018
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  841.84
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 0.99 0.010000000000000009
# ---------------------
# Status: Optimal
# Ale = 34.0
# Beer = 0.0
# Total Objective Value =  850.0
# Real Total Profit 850.0
# Total Barrels Made 34.0
# Weights 1.0 0.0
