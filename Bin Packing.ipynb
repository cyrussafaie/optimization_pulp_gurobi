# %%
from pulp import *

capacity = 45000
weight = [6780, 4010, 4720, 3950, 2870, 4070, 7550, 5760, 3350, 4290, 5600, 3400, 4240, 7760, 9380, 4400, 5810,
          6410, 6220, 9160, 5280, 3930, 8220, 2660, 5180]
weight2 = [6770, 4040, 4790, 3940, 2870, 4070, 7550, 5740, 3335, 4223, 5622, 3400, 4240, 7760, 9380, 4400, 5810,
           6370, 6220, 9160, 5280, 3990, 8240, 2660, 5140]
truck_rng = range(10)
load_rng = range(len(weight))
assignments = [(i,j) for i in truck_rng for j in load_rng]

#Define the problem
prob = LpProblem("BinPacking",LpMinimize)

# Two Sets of Variables
truck_vars = LpVariable.dicts("Trucks",truck_rng,lowBound=0,upBound=1,cat=LpContinuous)  # 1 if the truck is used, 0 otherwise
assign_vars = LpVariable.dicts("Assign",assignments, lowBound=0, upBound=1, cat=LpContinuous) # 1 if the truck i is assigned load j

# The objective function is added to 'prob' first
prob += lpSum([truck_vars[i] for i in truck_rng]), "Total Revenue of Production Plan"

# Contstraints that force all loads to be serviced
for y in load_rng:
    prob += lpSum([assign_vars[x,y] for x in truck_rng]) == 1

# Constraints for capacity of the trucks
for x in truck_rng: 
    prob += lpSum([weight[y]*assign_vars[x,y] for y in load_rng]) <= capacity

# Constraints to make sure that if you assign a load to a truck, you have to use that truck
for x in truck_rng:
    for y in load_rng:
        prob += [assign_vars[x,y]] <= truck_vars[x]

# The problem data is written to an .lp file
prob.writeLP("BinPack.lp")

# The problem is solved using PuLP's choice of Solver
prob.solve()

# The status of the solution is printed to the screen
print("Status:", LpStatus[prob.status])

# Each of the variables is printed with it's resolved optimum value
for v in prob.variables():
    print(v.name, "=", v.varValue)
    
# The optimised objective function value is printed to the screen
print("Total Trucks Used = ", value(prob.objective))
# Out:
# Status: Optimal
# Assign_(0,_0) = 0.0
# Assign_(0,_1) = 0.0
# Assign_(0,_10) = 0.0
# Assign_(0,_11) = 0.0
# Assign_(0,_12) = 0.0
# Assign_(0,_13) = 0.0
# Assign_(0,_14) = 0.0
# Assign_(0,_15) = 0.0
# Assign_(0,_16) = 0.0
# Assign_(0,_17) = 0.0
# Assign_(0,_18) = 0.0
# Assign_(0,_19) = 0.0
# Assign_(0,_2) = 0.0
# Assign_(0,_20) = 0.0
# Assign_(0,_21) = 0.0
# Assign_(0,_22) = 0.0
# Assign_(0,_23) = 0.0
# Assign_(0,_24) = 0.0
# Assign_(0,_3) = 0.0
# Assign_(0,_4) = 0.0
# Assign_(0,_5) = 0.0
# Assign_(0,_6) = 0.0
# Assign_(0,_7) = 0.0
# Assign_(0,_8) = 0.0
# Assign_(0,_9) = 0.0
# Assign_(1,_0) = 0.0
# Assign_(1,_1) = 0.0
# Assign_(1,_10) = 0.0
# Assign_(1,_11) = 0.0
# Assign_(1,_12) = 0.0
# Assign_(1,_13) = 0.0
# Assign_(1,_14) = 0.0
# Assign_(1,_15) = 0.0
# Assign_(1,_16) = 0.0
# Assign_(1,_17) = 0.0
# Assign_(1,_18) = 0.0
# Assign_(1,_19) = 0.0
# Assign_(1,_2) = 0.0
# Assign_(1,_20) = 0.0
# Assign_(1,_21) = 0.0
# Assign_(1,_22) = 0.0
# Assign_(1,_23) = 0.0
# Assign_(1,_24) = 0.0
# Assign_(1,_3) = 0.0
# Assign_(1,_4) = 0.0
# Assign_(1,_5) = 0.0
# Assign_(1,_6) = 0.0
# Assign_(1,_7) = 0.0
# Assign_(1,_8) = 0.0
# Assign_(1,_9) = 0.0
# Assign_(2,_0) = 0.0
# Assign_(2,_1) = 0.0
# Assign_(2,_10) = 0.0
# Assign_(2,_11) = 0.0
# Assign_(2,_12) = 0.0
# Assign_(2,_13) = 0.0
# Assign_(2,_14) = 0.0
# Assign_(2,_15) = 0.0
# Assign_(2,_16) = 0.0
# Assign_(2,_17) = 0.0
# Assign_(2,_18) = 0.0
# Assign_(2,_19) = 0.0
# Assign_(2,_2) = 0.0
# Assign_(2,_20) = 0.0
# Assign_(2,_21) = 0.0
# Assign_(2,_22) = 0.0
# Assign_(2,_23) = 0.0
# Assign_(2,_24) = 0.0
# Assign_(2,_3) = 0.0
# Assign_(2,_4) = 0.0
# Assign_(2,_5) = 0.0
# Assign_(2,_6) = 0.0
# Assign_(2,_7) = 0.0
# Assign_(2,_8) = 0.0
# Assign_(2,_9) = 0.0
# Assign_(3,_0) = 0.33333333
# Assign_(3,_1) = 0.33333333
# Assign_(3,_10) = 0.33333333
# Assign_(3,_11) = 0.33333333
# Assign_(3,_12) = 0.33333333
# Assign_(3,_13) = 0.33333333
# Assign_(3,_14) = 0.33333333
# Assign_(3,_15) = 0.33333333
# Assign_(3,_16) = 0.33333333
# Assign_(3,_17) = 0.33333333
# Assign_(3,_18) = 0.33333333
# Assign_(3,_19) = 0.33333333
# Assign_(3,_2) = 0.33333333
# Assign_(3,_20) = 0.33333333
# Assign_(3,_21) = 0.33333333
# Assign_(3,_22) = 0.33333333
# Assign_(3,_23) = 0.33333333
# Assign_(3,_24) = 0.33333333
# Assign_(3,_3) = 0.33333333
# Assign_(3,_4) = 0.33333333
# Assign_(3,_5) = 0.33333333
# Assign_(3,_6) = 0.33333333
# Assign_(3,_7) = 0.33333333
# Assign_(3,_8) = 0.33333333
# Assign_(3,_9) = 0.33333333
# Assign_(4,_0) = 0.0
# Assign_(4,_1) = 0.0
# Assign_(4,_10) = 0.0
# Assign_(4,_11) = 0.0
# Assign_(4,_12) = 0.0
# Assign_(4,_13) = 0.0
# Assign_(4,_14) = 0.0
# Assign_(4,_15) = 0.0
# Assign_(4,_16) = 0.0
# Assign_(4,_17) = 0.0
# Assign_(4,_18) = 0.0
# Assign_(4,_19) = 0.0
# Assign_(4,_2) = 0.0
# Assign_(4,_20) = 0.0
# Assign_(4,_21) = 0.0
# Assign_(4,_22) = 0.0
# Assign_(4,_23) = 0.0
# Assign_(4,_24) = 0.0
# Assign_(4,_3) = 0.0
# Assign_(4,_4) = 0.0
# Assign_(4,_5) = 0.0
# Assign_(4,_6) = 0.0
# Assign_(4,_7) = 0.0
# Assign_(4,_8) = 0.0
# Assign_(4,_9) = 0.0
# Assign_(5,_0) = 0.0
# Assign_(5,_1) = 0.0
# Assign_(5,_10) = 0.0
# Assign_(5,_11) = 0.0
# Assign_(5,_12) = 0.0
# Assign_(5,_13) = 0.0
# Assign_(5,_14) = 0.0
# Assign_(5,_15) = 0.0
# Assign_(5,_16) = 0.0
# Assign_(5,_17) = 0.0
# Assign_(5,_18) = 0.0
# Assign_(5,_19) = 0.0
# Assign_(5,_2) = 0.0
# Assign_(5,_20) = 0.0
# Assign_(5,_21) = 0.0
# Assign_(5,_22) = 0.0
# Assign_(5,_23) = 0.0
# Assign_(5,_24) = 0.0
# Assign_(5,_3) = 0.0
# Assign_(5,_4) = 0.0
# Assign_(5,_5) = 0.0
# Assign_(5,_6) = 0.0
# Assign_(5,_7) = 0.0
# Assign_(5,_8) = 0.0
# Assign_(5,_9) = 0.0
# Assign_(6,_0) = 0.33333333
# Assign_(6,_1) = 0.33333333
# Assign_(6,_10) = 0.33333333
# Assign_(6,_11) = 0.33333333
# Assign_(6,_12) = 0.33333333
# Assign_(6,_13) = 0.33333333
# Assign_(6,_14) = 0.33333333
# Assign_(6,_15) = 0.33333333
# Assign_(6,_16) = 0.33333333
# Assign_(6,_17) = 0.33333333
# Assign_(6,_18) = 0.33333333
# Assign_(6,_19) = 0.33333333
# Assign_(6,_2) = 0.33333333
# Assign_(6,_20) = 0.33333333
# Assign_(6,_21) = 0.33333333
# Assign_(6,_22) = 0.33333333
# Assign_(6,_23) = 0.33333333
# Assign_(6,_24) = 0.33333333
# Assign_(6,_3) = 0.33333333
# Assign_(6,_4) = 0.33333333
# Assign_(6,_5) = 0.33333333
# Assign_(6,_6) = 0.33333333
# Assign_(6,_7) = 0.33333333
# Assign_(6,_8) = 0.33333333
# Assign_(6,_9) = 0.33333333
# Assign_(7,_0) = 0.0
# Assign_(7,_1) = 0.0
# Assign_(7,_10) = 0.0
# Assign_(7,_11) = 0.0
# Assign_(7,_12) = 0.0
# Assign_(7,_13) = 0.0
# Assign_(7,_14) = 0.0
# Assign_(7,_15) = 0.0
# Assign_(7,_16) = 0.0
# Assign_(7,_17) = 0.0
# Assign_(7,_18) = 0.0
# Assign_(7,_19) = 0.0
# Assign_(7,_2) = 0.0
# Assign_(7,_20) = 0.0
# Assign_(7,_21) = 0.0
# Assign_(7,_22) = 0.0
# Assign_(7,_23) = 0.0
# Assign_(7,_24) = 0.0
# Assign_(7,_3) = 0.0
# Assign_(7,_4) = 0.0
# Assign_(7,_5) = 0.0
# Assign_(7,_6) = 0.0
# Assign_(7,_7) = 0.0
# Assign_(7,_8) = 0.0
# Assign_(7,_9) = 0.0
# Assign_(8,_0) = 0.33333333
# Assign_(8,_1) = 0.33333333
# Assign_(8,_10) = 0.33333333
# Assign_(8,_11) = 0.33333333
# Assign_(8,_12) = 0.33333333
# Assign_(8,_13) = 0.33333333
# Assign_(8,_14) = 0.33333333
# Assign_(8,_15) = 0.33333333
# Assign_(8,_16) = 0.33333333
# Assign_(8,_17) = 0.33333333
# Assign_(8,_18) = 0.33333333
# Assign_(8,_19) = 0.33333333
# Assign_(8,_2) = 0.33333333
# Assign_(8,_20) = 0.33333333
# Assign_(8,_21) = 0.33333333
# Assign_(8,_22) = 0.33333333
# Assign_(8,_23) = 0.33333333
# Assign_(8,_24) = 0.33333333
# Assign_(8,_3) = 0.33333333
# Assign_(8,_4) = 0.33333333
# Assign_(8,_5) = 0.33333333
# Assign_(8,_6) = 0.33333333
# Assign_(8,_7) = 0.33333333
# Assign_(8,_8) = 0.33333333
# Assign_(8,_9) = 0.33333333
# Assign_(9,_0) = 0.0
# Assign_(9,_1) = 0.0
# Assign_(9,_10) = 0.0
# Assign_(9,_11) = 0.0
# Assign_(9,_12) = 0.0
# Assign_(9,_13) = 0.0
# Assign_(9,_14) = 0.0
# Assign_(9,_15) = 0.0
# Assign_(9,_16) = 0.0
# Assign_(9,_17) = 0.0
# Assign_(9,_18) = 0.0
# Assign_(9,_19) = 0.0
# Assign_(9,_2) = 0.0
# Assign_(9,_20) = 0.0
# Assign_(9,_21) = 0.0
# Assign_(9,_22) = 0.0
# Assign_(9,_23) = 0.0
# Assign_(9,_24) = 0.0
# Assign_(9,_3) = 0.0
# Assign_(9,_4) = 0.0
# Assign_(9,_5) = 0.0
# Assign_(9,_6) = 0.0
# Assign_(9,_7) = 0.0
# Assign_(9,_8) = 0.0
# Assign_(9,_9) = 0.0
# Trucks_0 = 0.0
# Trucks_1 = 0.0
# Trucks_2 = 0.0
# Trucks_3 = 0.33333333
# Trucks_4 = 0.0
# Trucks_5 = 0.0
# Trucks_6 = 0.33333333
# Trucks_7 = 0.0
# Trucks_8 = 0.33333333
# Trucks_9 = 0.0
# Total Trucks Used =  0.99999999
